# %% [markdown]
# # __Testing Firebase Functions__

# %% [markdown]
# ### __auth.js__

# %%
import requests

token = "eyJhbGciOiJSUzI1NiIsImtpZCI6IjBhYmQzYTQzMTc4YzE0MjlkNWE0NDBiYWUzNzM1NDRjMDlmNGUzODciLCJ0eXAiOiJKV1QifQ.....hXdzsffppbsvgRu9nN-LrYShA6TkGYMKNvIs3lsuGd5WYM_8Q1M12y1jPWhpRofDmtUAVW3XMs9XEEWZ88oes6_wStsiXb52cf4IE7eLSQHiCY9oXce2348XDmxW8MGQkjX3pnaQSgRYvomy79zWStLav7LdWbVQ7D3JDrroIkQtBLhoGjZfUoKDaYNTG_2GUqbQ-lgcsjGp9jOm5NN0UnU68SJrecLNNGinYbAoage1YnCpP4zoDvg06Q5JtTThhT551sHDow2K5NXQRkOBSvHju-x3HiKJ-yxi6VNXE45hGaMqJDwrCgc6yAFPLEVqO3ThE9aU89feo873LEhoHA"
url = "http://127.0.0.1:5001/critics-4bf98/us-central1/verifyToken"
uid = None

try:
    # Send a POST request with the token in the body
    response = requests.post(url, json={'idToken': token}, timeout=5)
    
    if response.status_code == 200:
        print("Success!\nUID:", response.json()["uid"])
        uid = response.json()["uid"]
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)
# Out:
# Success!
# UID: SRAyBBj2eZMukclXmbsCKhZ7r1O2

# %% [markdown]
# ### __user.js__

# %%
uid = "SRAyBBj2eZMukclXmbsCKhZ7r1O2"

# %%
# Test creating a new user

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/createUser"

test_user = {
    "userId": uid,
    "username": 'geneva',
    "boards": ["board_001"]  # Optional test boards
}

try:
    # Send POST request to create user
    response = requests.post(url, json=test_user, timeout=5)
    
    if response.status_code == 200:
        print("User created successfully!")
        print("Response:", response.json())
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)
# Out:
# User created successfully!
# Response: {'success': True, 'user': {'name': 'geneva', 'boards': ['board_001']}}

# %%
# Test getting user's boards

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/getUserBoards"

try:
    # Send POST request to get user's boards
    response = requests.post(url, json={
        "userId": uid
    }, timeout=5) 
    
    if response.status_code == 200:
        print("Successfully retrieved user's boards!")
        print("Boards:", response.json()["boards"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)
# Out:
# Successfully retrieved user's boards!
# Boards: ['board_001']

# %%
# Test updating user's boards...use this to ADD or REMOVE boards from a user. 

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/updateUserBoards"

test_boards = ["board_001", "board_002", "board_003"]  # New boards to set

try:
    # Send POST request to update user's boards
    response = requests.post(url, json={
        "userId": uid,
        "boards": test_boards
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully updated user's boards!")
        print("Updated boards:", response.json()["boards"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)
# Out:
# Successfully updated user's boards!
# Updated boards: ['jay']

# %%
# Test removing a user from a board

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/removeUserFromBoard"

try:
    # Send POST request to remove user from board
    response = requests.post(url, json={
        "userId": uid,
        "boardId": "board_001"  # Replace with actual board ID
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully removed user from board!")
        print("Response:", response.json())
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)
# Out:
# Successfully removed user from board!
# Response: {'success': True, 'message': 'User removed from board successfully'}

# %%
# Test deleting a user

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/deleteUser"

try:
    # Send POST request to delete user
    response = requests.post(url, json={
        "userId": uid
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully deleted user!")
        print("Response:", response.json())
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)
# Out:
# Successfully deleted user!
# Response: {'success': True, 'message': 'User deleted successfully'}

# %% [markdown]
# ### __board.js__

# %%
# Test creating a board

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/createBoard"

try:
    # Send POST request to create board
    response = requests.post(url, json={
        "boardId": "board_201",
        "data": {
            "name": "NYC Restaurants",
            "description": "Best places to eat in New York",
            "categories": []  # Start with empty categories
        }
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully created board!")
        print("Board data:", response.json()["board"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test editing a board

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/editBoard"

try:
    # Send POST request to edit board
    response = requests.post(url, json={
        "boardId": "board_201",
        "data": {
            "name": "Updated NYC Restaurants",
            "description": "Updated description for NYC restaurants"
        }
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully updated board!")
        print("Updated board data:", response.json()["board"])
    elif response.status_code == 404:
        print("Not found:", response.json()["error"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test deleting a board

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/deleteBoard"

try:
    # Send POST request to delete board
    response = requests.post(url, json={
        "boardId": "board_201"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully deleted board!")
        print("Response:", response.json())
    elif response.status_code == 404:
        print("Not found:", response.json()["error"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test adding user to board

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/addUserToBoard"

try:
    # Send POST request to add user to board
    response = requests.post(url, json={
        "boardId": "board_201",
        "userId": "user_202"  # Different user than owner
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully added user to board!")
        print("Response:", response.json())
    elif response.status_code == 404:
        print("Not found:", response.json()["error"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test linking category to board

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/linkCategoryToBoard"

try:
    # Send POST request to link category
    response = requests.post(url, json={
        "boardId": "board_201",
        "categoryId": "category_003"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully linked category to board!")
        print("Response:", response.json())
    elif response.status_code == 404:
        print("Not found:", response.json()["error"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test unlinking category from board

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/unlinkCategoryFromBoard"

try:
    # Send POST request to unlink category
    response = requests.post(url, json={
        "boardId": "board_201",
        "categoryId": "category_003"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully unlinked category from board!")
        print("Response:", response.json())
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test getting board data

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/getBoardData"

try:
    # Send POST request to get board data
    response = requests.post(url, json={
        "boardId": "board_201"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully retrieved board data!")
        print("Board data:", response.json()["board"])
    elif response.status_code == 404:
        print("Not found:", response.json()["error"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test adding board to user

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/addBoardToUser"

try:
    # Send POST request to add board to user
    response = requests.post(url, json={
        "userId": "user_201",
        "boardCode": "board_201"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully added board to user!")
        print("Updated boards:", response.json()["boards"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %% [markdown]
# ### __category.js__

# %%
# Test creating a category

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/createCategory"

try:
    response = requests.post(url, json={
        "categoryId": "category_003",
        "name": "Italian Restaurants",
        "caption": "Best pasta and pizza spots",
        "boardId": "board_201"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully created category!")
        print("Category data:", response.json()["category"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test editing category name and caption

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/editCategoryNameCaption"

try:
    response = requests.post(url, json={
        "categoryId": "category_003",
        "name": "Updated Italian Spots",
        "caption": "Updated description for Italian restaurants"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully updated category!")
        print("Update data:", response.json()["update"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test adding restaurant to category

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/addRestaurantToCategory"

try:
    response = requests.post(url, json={
        "categoryId": "category_003",
        "restaurantId": "restaurant_201"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully added restaurant to category!")
        print("Updated restaurants:", response.json()["restaurants"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test removing restaurant from category

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/removeRestaurantFromCategory"

try:
    response = requests.post(url, json={
        "categoryId": "category_003",
        "restaurantId": "restaurant_201"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully removed restaurant from category!")
        print("Updated restaurants:", response.json()["restaurants"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test deleting a category

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/deleteCategory"

try:
    response = requests.post(url, json={
        "categoryId": "category_003",
        "boardId": "board_201"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully deleted category!")
        print("Response:", response.json())
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %% [markdown]
# ### __restaurant.js__

# %%
# Test creating a restaurant

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/createRestaurant"

try:
    response = requests.post(url, json={
        "categoryId": "category_003",
        "restaurantId": "restaurant_201",
        "data": {
            "name": "Carbone",
            "rating_1": 9.2,
            "rating_2": 8.5,
            "rating_3": 7.8,
            "notes": "Amazing Italian restaurant",
            "visits": ["2024-01-15"],
            "location": "New York, NY",
            "dishes": ["Spicy Rigatoni", "Veal Parmesan"],
            "photo": "https://example.com/photo.jpg"
        }
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully created restaurant!")
        print("Restaurant data:", response.json()["restaurant"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test editing a restaurant rating

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/editRating"

try:
    response = requests.post(url, json={
        "restaurantId": "restaurant_201",
        "ratingNumber": 2,
        "ratingValue": 8.8
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully updated rating!")
        print("Update data:", response.json()["update"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test editing restaurant notes

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/editNotes"

try:
    response = requests.post(url, json={
        "restaurantId": "restaurant_201",
        "notes": "Updated review: Still amazing Italian food!"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully updated notes!")
        print("Update data:", response.json()["update"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test adding a visit

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/addVisit"

try:
    response = requests.post(url, json={
        "restaurantId": "restaurant_201",
        "visitDate": "2024-01-20"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully added visit!")
        print("Updated visits:", response.json()["visits"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test deleting a visit

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/deleteVisit"

try:
    response = requests.post(url, json={
        "restaurantId": "restaurant_201"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully deleted visit!")
        print("Updated visits:", response.json()["visits"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test editing dish ranking

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/editDishRanking"

try:
    response = requests.post(url, json={
        "restaurantId": "restaurant_201",
        "dishes": ["Veal Parmesan", "Spicy Rigatoni", "Tiramisu"]
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully updated dishes!")
        print("Updated dishes:", response.json()["dishes"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test adding a dish

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/addDish"

try:
    response = requests.post(url, json={
        "restaurantId": "restaurant_201",
        "dish": "Lobster Fra Diavolo"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully added dish!")
        print("Updated dishes:", response.json()["dishes"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test deleting a dish

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/deleteDish"

try:
    response = requests.post(url, json={
        "restaurantId": "restaurant_201",
        "dish": "Lobster Fra Diavolo"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully deleted dish!")
        print("Updated dishes:", response.json()["dishes"])
    elif response.status_code == 404:
        print("Not found:", response.json()["error"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test switching restaurant category

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/switchRestaurantCategory"

try:
    response = requests.post(url, json={
        "restaurantId": "restaurant_201",
        "newCategoryId": "category_003"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully switched category!")
        print("Updated restaurant data:", response.json()["restaurant"])
    elif response.status_code == 404:
        print("Not found:", response.json()["error"])
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)

# %%
# Test deleting a restaurant

url = "http://127.0.0.1:5001/critics-4bf98/us-central1/deleteRestaurant"

try:
    response = requests.post(url, json={
        "restaurantId": "restaurant_201"
    }, timeout=5)
    
    if response.status_code == 200:
        print("Successfully deleted restaurant!")
        print("Response:", response.json())
    elif response.status_code == 400:
        print("Invalid input:", response.json()["error"])
    else:
        print(f"Error {response.status_code}:", response.text)
        
except requests.exceptions.RequestException as e:
    print("Error connecting to the function:", e)
